# %%
import pickle

with open('scaled_encoded_dataset.pkl', 'rb') as pickle_file:
    dataset = pickle.load(pickle_file)
    
dataset.head()
# Out:
#       age    workclass  fnlwgt    education  education-num  marital-status  \
# 4885   45  Non-Private  142719    Bachelors             13         Married
# 4886   34      Private  114973      HS-grad              9         Married
# 4887   33  Non-Private  159548   Assoc-acdm             12   Never-married
# 4888   43      Private   91209    Bachelors             13         Married
# 4889   28      Private  196564      HS-grad              9         Married
#
#            occupation relationship    race      sex  capital-gain  \
# 4885  Exec-managerial      Husband   White     Male             0
# 4886  Exec-managerial    Unmarried   White   Female             0
# 4887     Adm-clerical    Unmarried   Other   Female             0
# 4888  Exec-managerial      Husband   White     Male             0
# 4889     Craft-repair      Husband   White     Male             0
#
#       capital-loss  hours-per-week
# 4885             0              40
# 4886             0              30
# ...
